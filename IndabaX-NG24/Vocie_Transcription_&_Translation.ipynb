# %% [markdown]
# <a href="https://colab.research.google.com/github/owos/Talks/blob/main/IndabaX-NG24/Vocie_Transcription_%26_Translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hausa Transcription

# %%
#Dowload Files
# !wget https://github.com/owos/Talks/blob/main/IndabaX-NG24/audios/naija_vocies.mp3 -P /content/
# !wget https://raw.githubusercontent.com/owos/Talks/main/IndabaX-NG24/audios/nigerian_audio2.wav -P /content/
# !wget https://raw.githubusercontent.com/owos/Talks/main/IndabaX-NG24/audios/hausa_audio1.wav -P /content/
# !wget https://raw.githubusercontent.com/owos/Talks/main/IndabaX-NG24/audios/harvard.wav -P /content/
# Out:
# --2024-06-07 08:38:46--  https://github.com/owos/Talks/blob/main/IndabaX-NG24/audios/naija_vocies.mp3
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/naija_vocies.mp3’
#
# naija_vocies.mp3        [ <=>                ] 266.84K  --.-KB/s    in 0.02s
#
# 2024-06-07 08:38:46 (17.2 MB/s) - ‘/content/naija_vocies.mp3’ saved [273248]
#
# --2024-06-07 08:38:47--  https://raw.githubusercontent.com/owos/Talks/main/IndabaX-NG24/audios/nigerian_audio2.wav
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79941454 (76M) [application/octet-stream]
# ...

# %%
# Listen to the audio
import IPython.display as ipd
import librosa

print("Transcript: Ana noman masara sosai a arewacin Najeriya")
audio_path = "/content/hausa_audio1.wav"
audio, sr = librosa.load(audio_path, sr=16000)

ipd.Audio(audio_path, autoplay=False)
# Out:
# Transcript: Ana noman masara sosai a arewacin Najeriya
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# load model and processor
processor = WhisperProcessor.from_pretrained("DrishtiSharma/whisper-large-v2-hausa")
model = WhisperForConditionalGeneration.from_pretrained("DrishtiSharma/whisper-large-v2-hausa").to("cuda")

# Baghdad99/saad-speech-recognition-hausa-audio-to-text
forced_decoder_ids = processor.get_decoder_prompt_ids(language="hausa", task="transcribe")



input_features = processor(audio, sampling_rate=sr, return_tensors="pt").input_features.to("cuda")

# generate token ids
predicted_ids = model.generate(input_features, forced_decoder_ids=forced_decoder_ids)
# decode token ids to text
transcription = processor.batch_decode(predicted_ids)

transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)
# Out:
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/832 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.17G [00:00<?, ?B/s]

# %%
print(transcription[0])

# %% [markdown]
# ## Hausa Translation

# %%
forced_decoder_ids = processor.get_decoder_prompt_ids(language="english", task="translate")

input_features = processor(audio, sampling_rate=sr, return_tensors="pt").input_features.to("cuda")

# generate token ids
predicted_ids = model.generate(input_features, forced_decoder_ids=forced_decoder_ids)
# decode token ids to text
transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)
transcription

# %%
print(transcription[0])
